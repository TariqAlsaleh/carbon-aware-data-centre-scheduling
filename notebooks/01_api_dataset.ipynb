# %%
# Import libraries for file handling, web requests and data tables
import os
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor

# %%
print("Current folder:", os.getcwd())
# Out:
# Current folder: /Users/tariqalsaleh/PycharmProjects/CarbonIntensityProject/notebooks

# %%
# Function to download carbon intensity data from the UK API in weekly chunks
def fetch_carbon_intensity_range(start_utc: str, end_utc: str, chunk_days: int = 7) -> pd.DataFrame:

    # Convert the start and end dates into proper datetime format
    start = pd.to_datetime(start_utc, utc=True)
    end = pd.to_datetime(end_utc, utc=True)

    all_rows = []
    cur = start

    # Loop through the date range one week at a time
    while cur < end:
        # Set the end of this chunk to 7 days ahead or the final end date
        nxt = min(cur + pd.Timedelta(days=chunk_days), end)

        # Build the API URL for this week
        url = f"https://api.carbonintensity.org.uk/intensity/{cur:%Y-%m-%dT%H:%MZ}/{nxt:%Y-%m-%dT%H:%MZ}"

        # Send the request and check it worked
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        data = r.json()["data"]

        # Save each 30 minute reading to the list
        for rec in data:
            all_rows.append({
                "from": rec["from"],
                "to": rec["to"],
                "forecast": rec["intensity"]["forecast"],
                "actual": rec["intensity"]["actual"],
                "index": rec["intensity"]["index"],
            })

        print(f"Fetched: {cur:%Y-%m-%d} → {nxt:%Y-%m-%d} | rows so far: {len(all_rows)}")
        cur = nxt

    # Put all rows into a table and sort by time
    df = pd.DataFrame(all_rows)
    df["from"] = pd.to_datetime(df["from"], utc=True)
    df["to"] = pd.to_datetime(df["to"], utc=True)
    df = df.sort_values("from").set_index("from")

    return df

# Download two years of data from Jan 2023 to Dec 2024
api_big_df = fetch_carbon_intensity_range(
    start_utc="2023-01-01T00:00Z",
    end_utc="2024-12-31T23:00Z",
    chunk_days=7
)

# Save the data as a CSV so it does not need to be downloaded again
os.makedirs("data", exist_ok=True)
out_path = os.path.join("data", "gb_carbonintensity_api_2023_2024.csv")
api_big_df.to_csv(out_path)
print("Saved to:", out_path)
# Out:
# Fetched: 2023-01-01 → 2023-01-08 | rows so far: 337
# Fetched: 2023-01-08 → 2023-01-15 | rows so far: 674
# Fetched: 2023-01-15 → 2023-01-22 | rows so far: 1011
# Fetched: 2023-01-22 → 2023-01-29 | rows so far: 1348
# Fetched: 2023-01-29 → 2023-02-05 | rows so far: 1685
# Fetched: 2023-02-05 → 2023-02-12 | rows so far: 2022
# Fetched: 2023-02-12 → 2023-02-19 | rows so far: 2359
# Fetched: 2023-02-19 → 2023-02-26 | rows so far: 2696
# Fetched: 2023-02-26 → 2023-03-05 | rows so far: 3033
# Fetched: 2023-03-05 → 2023-03-12 | rows so far: 3370
# Fetched: 2023-03-12 → 2023-03-19 | rows so far: 3707
# Fetched: 2023-03-19 → 2023-03-26 | rows so far: 4044
# Fetched: 2023-03-26 → 2023-04-02 | rows so far: 4381
# Fetched: 2023-04-02 → 2023-04-09 | rows so far: 4718
# Fetched: 2023-04-09 → 2023-04-16 | rows so far: 5055
# Fetched: 2023-04-16 → 2023-04-23 | rows so far: 5392
# Fetched: 2023-04-23 → 2023-04-30 | rows so far: 5729
# Fetched: 2023-04-30 → 2023-05-07 | rows so far: 6066
# Fetched: 2023-05-07 → 2023-05-14 | rows so far: 6403
# Fetched: 2023-05-14 → 2023-05-21 | rows so far: 6740
# Fetched: 2023-05-21 → 2023-05-28 | rows so far: 7077
# Fetched: 2023-05-28 → 2023-06-04 | rows so far: 7414
# Fetched: 2023-06-04 → 2023-06-11 | rows so far: 7751
# Fetched: 2023-06-11 → 2023-06-18 | rows so far: 8088
# Fetched: 2023-06-18 → 2023-06-25 | rows so far: 8425
# Fetched: 2023-06-25 → 2023-07-02 | rows so far: 8762
# Fetched: 2023-07-02 → 2023-07-09 | rows so far: 9099
# Fetched: 2023-07-09 → 2023-07-16 | rows so far: 9436
# Fetched: 2023-07-16 → 2023-07-23 | rows so far: 9773
# Fetched: 2023-07-23 → 2023-07-30 | rows so far: 10110
# Fetched: 2023-07-30 → 2023-08-06 | rows so far: 10447
# Fetched: 2023-08-06 → 2023-08-13 | rows so far: 10784
# Fetched: 2023-08-13 → 2023-08-20 | rows so far: 11121
# Fetched: 2023-08-20 → 2023-08-27 | rows so far: 11458
# Fetched: 2023-08-27 → 2023-09-03 | rows so far: 11795
# Fetched: 2023-09-03 → 2023-09-10 | rows so far: 12132
# Fetched: 2023-09-10 → 2023-09-17 | rows so far: 12469
# Fetched: 2023-09-17 → 2023-09-24 | rows so far: 12806
# Fetched: 2023-09-24 → 2023-10-01 | rows so far: 13143
# Fetched: 2023-10-01 → 2023-10-08 | rows so far: 13480
# Fetched: 2023-10-08 → 2023-10-15 | rows so far: 13817
# Fetched: 2023-10-15 → 2023-10-22 | rows so far: 14102
# Fetched: 2023-10-22 → 2023-10-29 | rows so far: 14399
# Fetched: 2023-10-29 → 2023-11-05 | rows so far: 14736
# Fetched: 2023-11-05 → 2023-11-12 | rows so far: 15073
# Fetched: 2023-11-12 → 2023-11-19 | rows so far: 15410
# Fetched: 2023-11-19 → 2023-11-26 | rows so far: 15747
# Fetched: 2023-11-26 → 2023-12-03 | rows so far: 16084
# Fetched: 2023-12-03 → 2023-12-10 | rows so far: 16421
# Fetched: 2023-12-10 → 2023-12-17 | rows so far: 16758
# Fetched: 2023-12-17 → 2023-12-24 | rows so far: 17095
# Fetched: 2023-12-24 → 2023-12-31 | rows so far: 17432
# Fetched: 2023-12-31 → 2024-01-07 | rows so far: 17769
# Fetched: 2024-01-07 → 2024-01-14 | rows so far: 18106
# Fetched: 2024-01-14 → 2024-01-21 | rows so far: 18443
# Fetched: 2024-01-21 → 2024-01-28 | rows so far: 18780
# Fetched: 2024-01-28 → 2024-02-04 | rows so far: 19117
# Fetched: 2024-02-04 → 2024-02-11 | rows so far: 19454
# Fetched: 2024-02-11 → 2024-02-18 | rows so far: 19791
# Fetched: 2024-02-18 → 2024-02-25 | rows so far: 20128
# Fetched: 2024-02-25 → 2024-03-03 | rows so far: 20465
# Fetched: 2024-03-03 → 2024-03-10 | rows so far: 20802
# Fetched: 2024-03-10 → 2024-03-17 | rows so far: 21139
# Fetched: 2024-03-17 → 2024-03-24 | rows so far: 21476
# Fetched: 2024-03-24 → 2024-03-31 | rows so far: 21813
# Fetched: 2024-03-31 → 2024-04-07 | rows so far: 22150
# Fetched: 2024-04-07 → 2024-04-14 | rows so far: 22487
# Fetched: 2024-04-14 → 2024-04-21 | rows so far: 22824
# Fetched: 2024-04-21 → 2024-04-28 | rows so far: 23161
# Fetched: 2024-04-28 → 2024-05-05 | rows so far: 23498
# Fetched: 2024-05-05 → 2024-05-12 | rows so far: 23835
# Fetched: 2024-05-12 → 2024-05-19 | rows so far: 24172
# Fetched: 2024-05-19 → 2024-05-26 | rows so far: 24509
# Fetched: 2024-05-26 → 2024-06-02 | rows so far: 24846
# Fetched: 2024-06-02 → 2024-06-09 | rows so far: 25183
# Fetched: 2024-06-09 → 2024-06-16 | rows so far: 25489
# Fetched: 2024-06-16 → 2024-06-23 | rows so far: 25826
# Fetched: 2024-06-23 → 2024-06-30 | rows so far: 26163
# Fetched: 2024-06-30 → 2024-07-07 | rows so far: 26500
# Fetched: 2024-07-07 → 2024-07-14 | rows so far: 26837
# Fetched: 2024-07-14 → 2024-07-21 | rows so far: 27174
# Fetched: 2024-07-21 → 2024-07-28 | rows so far: 27511
# Fetched: 2024-07-28 → 2024-08-04 | rows so far: 27848
# Fetched: 2024-08-04 → 2024-08-11 | rows so far: 28185
# Fetched: 2024-08-11 → 2024-08-18 | rows so far: 28522
# Fetched: 2024-08-18 → 2024-08-25 | rows so far: 28859
# Fetched: 2024-08-25 → 2024-09-01 | rows so far: 29196
# Fetched: 2024-09-01 → 2024-09-08 | rows so far: 29533
# Fetched: 2024-09-08 → 2024-09-15 | rows so far: 29870
# Fetched: 2024-09-15 → 2024-09-22 | rows so far: 30207
# Fetched: 2024-09-22 → 2024-09-29 | rows so far: 30544
# Fetched: 2024-09-29 → 2024-10-06 | rows so far: 30881
# Fetched: 2024-10-06 → 2024-10-13 | rows so far: 31218
# Fetched: 2024-10-13 → 2024-10-20 | rows so far: 31555
# Fetched: 2024-10-20 → 2024-10-27 | rows so far: 31892
# Fetched: 2024-10-27 → 2024-11-03 | rows so far: 32229
# Fetched: 2024-11-03 → 2024-11-10 | rows so far: 32566
# Fetched: 2024-11-10 → 2024-11-17 | rows so far: 32903
# Fetched: 2024-11-17 → 2024-11-24 | rows so far: 33240
# Fetched: 2024-11-24 → 2024-12-01 | rows so far: 33577
# Fetched: 2024-12-01 → 2024-12-08 | rows so far: 33914
# Fetched: 2024-12-08 → 2024-12-15 | rows so far: 34251
# Fetched: 2024-12-15 → 2024-12-22 | rows so far: 34588
# Fetched: 2024-12-22 → 2024-12-29 | rows so far: 34925
# Fetched: 2024-12-29 → 2024-12-31 | rows so far: 35068
# Saved to: data/gb_carbonintensity_api_2023_2024.csv

# %%
df_api = pd.read_csv(
    "data/gb_carbonintensity_api_2023_2024.csv",
    parse_dates=["from", "to"]
)

print(df_api.shape)
df_api.head()
# Out:
# (35068, 5)
#                        from                        to  forecast  actual index
# 0 2022-12-31 23:30:00+00:00 2023-01-01 00:00:00+00:00        75    65.0   low
# 1 2023-01-01 00:00:00+00:00 2023-01-01 00:30:00+00:00        73    72.0   low
# 2 2023-01-01 00:30:00+00:00 2023-01-01 01:00:00+00:00        63    80.0   low
# 3 2023-01-01 01:00:00+00:00 2023-01-01 01:30:00+00:00        71    72.0   low
# 4 2023-01-01 01:30:00+00:00 2023-01-01 02:00:00+00:00        76    65.0   low

# %%
df_api = df_api.set_index("from").sort_index()

df_api.head()
# Out:
#                                                  to  forecast  actual index
# from
# 2022-12-31 23:30:00+00:00 2023-01-01 00:00:00+00:00        75    65.0   low
# 2023-01-01 00:00:00+00:00 2023-01-01 00:30:00+00:00        73    72.0   low
# 2023-01-01 00:30:00+00:00 2023-01-01 01:00:00+00:00        63    80.0   low
# 2023-01-01 01:00:00+00:00 2023-01-01 01:30:00+00:00        71    72.0   low
# 2023-01-01 01:30:00+00:00 2023-01-01 02:00:00+00:00        76    65.0   low

# %%
# Keeping only the target I want to model
df_api2 = df_api[["actual"]].copy()

# Make sure it's numeric (sometimes it loads as text)
df_api2["actual"] = pd.to_numeric(df_api2["actual"], errors="coerce")

# Drop any missing rows created by conversion
df_api2 = df_api2.dropna()

df_api2.head()
# Out:
#                            actual
# from
# 2022-12-31 23:30:00+00:00    65.0
# 2023-01-01 00:00:00+00:00    72.0
# 2023-01-01 00:30:00+00:00    80.0
# 2023-01-01 01:00:00+00:00    72.0
# 2023-01-01 01:30:00+00:00    65.0

# %%
df_hourly = df_api2.resample("1h").mean()

print(df_hourly.shape)
df_hourly.head()
# Out:
# (17544, 1)
#                            actual
# from
# 2022-12-31 23:00:00+00:00    65.0
# 2023-01-01 00:00:00+00:00    76.0
# 2023-01-01 01:00:00+00:00    68.5
# 2023-01-01 02:00:00+00:00    65.0
# 2023-01-01 03:00:00+00:00    67.5

# %%
df_ml = df_hourly.rename(columns={"actual": "carbon_intensity"}).copy()
df_ml.head()
# Out:
#                            carbon_intensity
# from
# 2022-12-31 23:00:00+00:00              65.0
# 2023-01-01 00:00:00+00:00              76.0
# 2023-01-01 01:00:00+00:00              68.5
# 2023-01-01 02:00:00+00:00              65.0
# 2023-01-01 03:00:00+00:00              67.5

# %%
# df_hourly: has datetime index and a single column 'carbon_intensity'
df_ml = df_hourly.rename(columns={"actual": "carbon_intensity"}).copy()

# Target = next hour value (t+1)
df_ml["target_next_hour"] = df_ml["carbon_intensity"].shift(-1)

df_ml[["carbon_intensity", "target_next_hour"]].head()
# Out:
#                            carbon_intensity  target_next_hour
# from
# 2022-12-31 23:00:00+00:00              65.0              76.0
# 2023-01-01 00:00:00+00:00              76.0              68.5
# 2023-01-01 01:00:00+00:00              68.5              65.0
# 2023-01-01 02:00:00+00:00              65.0              67.5
# 2023-01-01 03:00:00+00:00              67.5              72.0

# %%
for lag in range(1, 25):  # 1..24
    df_ml[f"lag_{lag}"] = df_ml["carbon_intensity"].shift(lag)

# %%
df_ml = df_ml.dropna()

print("Final ML table shape:", df_ml.shape)
df_ml.head()
# Out:
# Final ML table shape: (17382, 26)
#                            carbon_intensity  target_next_hour  lag_1  lag_2  \
# from
# 2023-01-01 23:00:00+00:00             152.5             140.5  151.5  159.0
# 2023-01-02 00:00:00+00:00             140.5             128.0  152.5  151.5
# 2023-01-02 01:00:00+00:00             128.0             124.5  140.5  152.5
# 2023-01-02 02:00:00+00:00             124.5             120.0  128.0  140.5
# 2023-01-02 03:00:00+00:00             120.0             124.0  124.5  128.0
#
#                            lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  ...  \
# from                                                                 ...
# 2023-01-01 23:00:00+00:00  163.0  162.0  159.0  161.0  152.5  137.0  ...
# 2023-01-02 00:00:00+00:00  159.0  163.0  162.0  159.0  161.0  152.5  ...
# 2023-01-02 01:00:00+00:00  151.5  159.0  163.0  162.0  159.0  161.0  ...
# 2023-01-02 02:00:00+00:00  152.5  151.5  159.0  163.0  162.0  159.0  ...
# 2023-01-02 03:00:00+00:00  140.5  152.5  151.5  159.0  163.0  162.0  ...
#
#                            lag_15  lag_16  lag_17  lag_18  lag_19  lag_20  \
# from
# 2023-01-01 23:00:00+00:00    77.5    74.5    72.5    72.5    72.0    67.5
# 2023-01-02 00:00:00+00:00    78.0    77.5    74.5    72.5    72.5    72.0
# 2023-01-02 01:00:00+00:00    85.0    78.0    77.5    74.5    72.5    72.5
# 2023-01-02 02:00:00+00:00    89.5    85.0    78.0    77.5    74.5    72.5
# 2023-01-02 03:00:00+00:00    91.5    89.5    85.0    78.0    77.5    74.5
#
#                            lag_21  lag_22  lag_23  lag_24
# from
# 2023-01-01 23:00:00+00:00    65.0    68.5    76.0    65.0
# 2023-01-02 00:00:00+00:00    67.5    65.0    68.5    76.0
# 2023-01-02 01:00:00+00:00    72.0    67.5    65.0    68.5
# 2023-01-02 02:00:00+00:00    72.5    72.0    67.5    65.0
# 2023-01-02 03:00:00+00:00    72.5    72.5    72.0    67.5
#
# [5 rows x 26 columns]

# %%
train = df_ml.loc["2024-01-01":"2024-10-31"]
test  = df_ml.loc["2024-11-01":"2024-12-31"]

feature_cols = [f"lag_{i}" for i in range(1, 25)]
X_train = train[feature_cols].values
y_train = train["target_next_hour"].values

X_test  = test[feature_cols].values
y_test  = test["target_next_hour"].values

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape, y_test.shape)
# Out:
# Train: (7280, 24) (7280,)
# Test : (1462, 24) (1462,)

# %%
ts = test.index[0]
print("Test row timestamp (t):", ts)
print("Last hour used (lag_1 = t-1):", test.loc[ts, "lag_1"])
print("Target (next hour y = t+1):", test.loc[ts, "target_next_hour"])

print("Actual at t+1 from series:", df_hourly.loc[ts + pd.Timedelta(hours=1), "actual"])
# Out:
# Test row timestamp (t): 2024-11-01 00:00:00+00:00
# Last hour used (lag_1 = t-1): 129.5
# Target (next hour y = t+1): 122.5
# Actual at t+1 from series: 122.5

# %%
model = Ridge(alpha=1.0)  #regularisation - penalty for larger weights
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
# Save a small file for the scheduler (this is only ~1462 rows)
os.makedirs("data", exist_ok=True)

pred_df = pd.DataFrame({
    "time": test.index,          # timestamps for each prediction
    "ci_actual": y_test,         # actual next-hour CI
    "ci_pred": y_pred            # predicted next-hour CI
})

pred_df.to_csv("data/ci_pred_nov_dec_2024.csv", index=False)
print("Saved:", "data/ci_pred_nov_dec_2024.csv", "| rows:", len(pred_df))
pred_df.head()
# Out:
# Saved: data/ci_pred_nov_dec_2024.csv | rows: 1462
#                        time  ci_actual     ci_pred
# 0 2024-11-01 00:00:00+00:00      122.5  114.634265
# 1 2024-11-01 01:00:00+00:00      115.0  123.113429
# 2 2024-11-01 02:00:00+00:00      106.5  122.690383
# 3 2024-11-01 03:00:00+00:00      105.5  116.772964
# 4 2024-11-01 04:00:00+00:00      122.0  120.844563

# %%
mae = np.mean(np.abs(y_test - y_pred))
rmse = np.sqrt(np.mean((y_test - y_pred)**2))

print(f"Ridge → MAE: {mae:.2f} gCO2/kWh")
print(f"Ridge → RMSE: {rmse:.2f} gCO2/kWh")
# Out:
# Ridge → MAE: 10.59 gCO2/kWh
# Ridge → RMSE: 14.55 gCO2/kWh

# %%
hours = 24 * 9  # 9 days

plt.figure(figsize=(12,4))
plt.plot(test.index[:hours], y_test[:hours], label="Actual")
plt.plot(test.index[:hours], y_pred[:hours], label="Predicted")
plt.title("Next-hour Carbon Intensity Forecast (Test Period)")
plt.ylabel("gCO2/kWh")
plt.xlabel("Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
y_persist = X_test[:, 0]  # lag_1

mae_persist = np.mean(np.abs(y_test - y_persist))
rmse_persist = np.sqrt(np.mean((y_test - y_persist)**2))

print(f"Persistence → MAE: {mae_persist:.2f}, RMSE: {rmse_persist:.2f}")
# Out:
# Persistence → MAE: 14.06, RMSE: 20.65

# %%
hours = 24 * 5  # show 5 days (cleaner than 9)
t = test.index[:hours]

plt.figure(figsize=(16,6))
plt.plot(t, y_test[:hours], label="Actual")
plt.plot(t, y_pred[:hours], label="Predicted")

plt.title("Next-hour Carbon Intensity Forecast (Test Period)", fontsize=28)
plt.ylabel("gCO₂/kWh", fontsize=24)
plt.xlabel("Time", fontsize=24)
plt.legend(fontsize=20)
plt.grid(True)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.tight_layout()

plt.savefig("fig_next_hour_forecast.pdf", bbox_inches="tight")
plt.savefig("fig_next_hour_forecast.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
week = df_hourly.loc["2024-11-01":"2024-11-08"]  # 1 week

plt.figure(figsize=(16,5))
plt.plot(week.index, week["actual"], label="Carbon intensity")
plt.title("UK Grid Carbon Intensity (Example Week)", fontsize=28)
plt.ylabel("gCO₂/kWh", fontsize=24)
plt.xlabel("Time", fontsize=24)
plt.grid(True)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.tight_layout()

plt.savefig("fig_data_overview_week.pdf", bbox_inches="tight", facecolor="white")
plt.savefig("fig_data_overview_week.png", dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

# %%
err = y_test[:hours] - y_pred[:hours]

plt.figure(figsize=(16,4))
plt.plot(t, err)
plt.axhline(0, linewidth=2)
plt.title("Forecast Error (Actual − Predicted)", fontsize=26)
plt.ylabel("gCO₂/kWh", fontsize=22)
plt.xlabel("Time", fontsize=22)
plt.grid(True)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()

plt.savefig("fig_forecast_error.pdf", bbox_inches="tight")
plt.savefig("fig_forecast_error.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
results_table = pd.DataFrame({
    "Model": ["Persistence (baseline)", "Ridge (lags 1–24)"],
    "MAE (gCO₂/kWh)": [mae_persist, mae],
    "RMSE (gCO₂/kWh)": [rmse_persist, rmse],
})

results_table.to_csv("table_results_next_hour.csv", index=False)
results_table
# Out:
#                     Model  MAE (gCO₂/kWh)  RMSE (gCO₂/kWh)
# 0  Persistence (baseline)       14.059166        20.652340
# 1       Ridge (lags 1–24)       10.586092        14.552409

# %%
hours = 24 * 5
t = test.index[:hours]

plt.figure(figsize=(16,6))
plt.plot(t, y_test[:hours], label="Actual")
plt.plot(t, y_pred[:hours], label="Predicted")

plt.title("Next-hour Carbon Intensity Forecast (Test Period)", fontsize=28)
plt.ylabel("gCO₂/kWh", fontsize=24)
plt.xlabel("Time", fontsize=24)
plt.legend(fontsize=20)
plt.grid(True)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.tight_layout()

plt.savefig("fig_next_hour_forecast.svg", bbox_inches="tight", facecolor="white")
plt.savefig("fig_next_hour_forecast.pdf", bbox_inches="tight", facecolor="white")

plt.savefig("fig_next_hour_forecast.png", dpi=300, bbox_inches="tight", facecolor="white")

plt.show()

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

mae_rf = np.mean(np.abs(y_test - y_pred_rf))
rmse_rf = np.sqrt(np.mean((y_test - y_pred_rf)**2))

print(f"Random Forest → MAE: {mae_rf:.2f}")
print(f"Random Forest → RMSE: {rmse_rf:.2f}")
# Out:
# Random Forest → MAE: 11.86
# Random Forest → RMSE: 16.17

# %%
results_table = pd.DataFrame({
    "Model": ["Persistence", "Ridge", "Random Forest"],
    "MAE (gCO2/kWh)": [mae_persist, mae, mae_rf],
    "RMSE (gCO2/kWh)": [rmse_persist, rmse, rmse_rf],
})
results_table
# Out:
#            Model  MAE (gCO2/kWh)  RMSE (gCO2/kWh)
# 0    Persistence       14.059166        20.652340
# 1          Ridge       10.586092        14.552409
# 2  Random Forest       11.857777        16.172485

# %%
hours = 24 * 5
t = test.index[:hours]

plt.figure(figsize=(16, 6))
plt.plot(t, y_test[:hours],    label="Actual",       linewidth=2)
plt.plot(t, y_persist[:hours], label="Persistence",  linewidth=1.5, linestyle="--")
plt.plot(t, y_pred[:hours],    label="Ridge",        linewidth=1.5)
plt.plot(t, y_pred_rf[:hours], label="Random Forest",linewidth=1.5)

plt.title("Next-hour Carbon Intensity — Model Comparison", fontsize=26)
plt.ylabel("gCO₂/kWh", fontsize=22)
plt.xlabel("Time", fontsize=22)
plt.legend(fontsize=18)
plt.grid(True)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()

plt.savefig("fig_model_comparison.png", dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.hist(y_test - y_persist, bins=60, alpha=0.5, label="Persistence")
plt.hist(y_test - y_pred,    bins=60, alpha=0.5, label="Ridge")
plt.hist(y_test - y_pred_rf, bins=60, alpha=0.5, label="Random Forest")
plt.axvline(0, color="black", linewidth=1.5)
plt.title("Forecast Error Distribution", fontsize=22)
plt.xlabel("Error (gCO₂/kWh)", fontsize=18)
plt.ylabel("Frequency", fontsize=18)
plt.legend(fontsize=16)
plt.grid(True)
plt.tight_layout()
plt.savefig("fig_error_distribution.png", dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

# %%
# Calculate mean carbon intensity over test period
mean_ci = y_test.mean()

# Calculate MAPE for each model
mape_ridge = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
mape_persist = np.mean(np.abs((y_test - y_persist) / y_test)) * 100
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / y_test)) * 100

print(f"Mean carbon intensity (test period): {mean_ci:.2f} gCO2/kWh")
print(f"Persistence MAPE: {mape_persist:.2f}%")
print(f"Ridge MAPE: {mape_ridge:.2f}%")
print(f"Random Forest MAPE: {mape_rf:.2f}%")
# Out:
# Mean carbon intensity (test period): 148.91 gCO2/kWh
# Persistence MAPE: 11.84%
# Ridge MAPE: 9.22%
# Random Forest MAPE: 10.16%
